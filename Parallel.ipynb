# %%
import dask.dataframe as dd
from dask.distributed import Client

# %%
client = Client()
client
# Out:
# c:\Users\Acer\AppData\Local\Programs\Python\Python310\lib\site-packages\distributed\node.py:183: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 52023 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:52024' processes=4 threads=8, memory=19.88 GiB>

# %%
ddf = dd.read_parquet(
    "s3://dask-data/nyc-taxi/nyc-2015.parquet/part.*.parquet",
    columns=["passenger_count", "tip_amount"],
    storage_options={"anon": True},
)

# %%
result = ddf.groupby("passenger_count").tip_amount.mean().compute()
result
